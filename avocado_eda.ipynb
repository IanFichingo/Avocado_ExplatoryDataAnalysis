# %% [markdown]
# # Avocado Exploratory data analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# loading the dataset
df = pd.read_csv('Avocado.csv')

# %% [markdown]
# ## Understanding the data

# %%
# first 3 rows
df.head(3)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany

# %%
# last 3 rows
df.tail(3)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
# number of rows and columns
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# There is 18249 rows and 14 columns
# ***

# %%
# checking unique values
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# ***

# %%
# descriptive summary statistics
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %% [markdown]
# ***

# %% [markdown]
# ## Data cleaning

# %%
# checking missing values
# No missing values
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# dropping unnecessary columns
df1 = df.drop(['Unnamed: 0', '4046', '4225', '4770', 'XLarge Bags'], axis=1)
df1.head(3)
# Out:
#          Date  AveragePrice  Total Volume  Total Bags  Small Bags  Large Bags  \
# 0  2015-12-27          1.33      64236.62     8696.87     8603.62       93.25
# 1  2015-12-20          1.35      54876.98     9505.56     9408.07       97.49
# 2  2015-12-13          0.93     118220.22     8145.35     8042.21      103.14
#
#            type  year  region
# 0  conventional  2015  Albany
# 1  conventional  2015  Albany
# 2  conventional  2015  Albany

# %% [markdown]
# ***

# %% [markdown]
# ## Relationship Analysis

# %% [markdown]
# ### Checking data distribution using histograms

# %%
# checking for distributions of variables
# visualization using seaborn
sns.distplot(df1['AveragePrice'])

# %%
sns.distplot(df1['Total Volume'])

# %%
sns.distplot(df1['Total Bags'])

# %%
sns.distplot(df1['Small Bags'])

# %%
sns.distplot(df1['Large Bags'])

# %% [markdown]
# ***

# %% [markdown]
# ### checking the relationships between variables using scatter plots

# %%
# using scatter plots to find linear relationships
plt.scatter(x= 'Total Volume', y='AveragePrice', data=df1)

# %%
plt.scatter(x= 'Total Bags', y='AveragePrice', data=df1)

# %%
plt.scatter(x= 'Small Bags', y='AveragePrice', data=df1)

# %%
plt.scatter(x= 'Large Bags', y='AveragePrice', data=df1)

# %% [markdown]
# ***

# %%
sns.pairplot(df1)
